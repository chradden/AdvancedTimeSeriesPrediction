# %% [markdown]
# # Explorative Datenanalyse - Energiedaten
#
# **Ziel:** Erste Analyse der Energiedaten von SMARD (Bundesnetzagentur)
#
# **Inhalte:**
# 1. Daten laden
# 2. Datenqualität prüfen
# 3. Grundlegende Visualisierungen
# 4. Statistische Eigenschaften
# 5. Saisonalität & Trends
# 6. Autokorrelation

# %%
# Standard imports
import sys
sys.path.append('../src')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Visualization settings
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette('husl')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# Figure size
plt.rcParams['figure.figsize'] = (15, 6)
plt.rcParams['font.size'] = 11

print("✅ Libraries loaded successfully")
# Out:
# ✅ Libraries loaded successfully

# %% [markdown]
# ## 1. Daten laden
#
# Wir nutzen die SMARD API der Bundesnetzagentur.
#
# **Verfügbare Datenquellen:**
# - `solar`: Photovoltaik-Erzeugung
# - `wind_onshore`: Windkraft Onshore
# - `wind_offshore`: Windkraft Offshore
# - `consumption`: Stromverbrauch
# - `price_day_ahead`: Day-Ahead Marktpreis
# - `generation_total`: Gesamte Stromerzeugung
# - Weitere siehe `src/data/smard_loader.py`

# %%
from data.smard_loader import load_smard_data, SMARDDataLoader

# Konfiguration
DATA_TYPE = 'solar'  # Ändere hier für andere Datenquellen
START_DATE = '2022-01-01'
END_DATE = '2024-12-31'
RESOLUTION = 'hour'

print(f"Lade {DATA_TYPE}-Daten von {START_DATE} bis {END_DATE}...\n")
# Out:
# Lade solar-Daten von 2022-01-01 bis 2024-12-31...

# %%
# Daten laden (wird gecached für schnelleres Nachladen)
df = load_smard_data(
    filter_name=DATA_TYPE,
    start_date=START_DATE,
    end_date=END_DATE,
    resolution=RESOLUTION,
    cache_dir=Path('../data/raw')
)

print(f"\n✅ Daten erfolgreich geladen: {len(df)} Datenpunkte")
# Out:
# Downloading solar data from SMARD API...
# Period: 2022-01-01 to 2024-12-31
# Downloading 157 chunks...
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1641164400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1641769200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1642374000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1642978800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1643583600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1644188400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1644793200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1645398000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1646002800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1646607600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1647212400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1647817200000.json
#     Downloaded 167 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1648418400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1649023200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1649628000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1650232800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1650837600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1651442400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1652047200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1652652000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1653256800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1653861600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1654466400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1655071200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1655676000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1656280800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1656885600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1657490400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1658095200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1658700000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1659304800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1659909600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1660514400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1661119200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1661724000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1662328800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1662933600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1663538400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1664143200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1664748000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1665352800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1665957600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1666562400000.json
#     Downloaded 169 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1667170800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1667775600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1668380400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1668985200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1669590000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1670194800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1670799600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1671404400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1672009200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1672614000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1673218800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1673823600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1674428400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1675033200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1675638000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1676242800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1676847600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1677452400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1678057200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1678662000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1679266800000.json
#     Downloaded 167 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1679868000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1680472800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1681077600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1681682400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1682287200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1682892000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1683496800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1684101600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1684706400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1685311200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1685916000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1686520800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1687125600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1687730400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1688335200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1688940000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1689544800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1690149600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1690754400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1691359200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1691964000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1692568800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1693173600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1693778400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1694383200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1694988000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1695592800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1696197600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1696802400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1697407200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1698012000000.json
#     Downloaded 169 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1698620400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1699225200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1699830000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1700434800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1701039600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1701644400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1702249200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1702854000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1703458800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1704063600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1704668400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1705273200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1705878000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1706482800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1707087600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1707692400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1708297200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1708902000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1709506800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1710111600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1710716400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1711321200000.json
#     Downloaded 167 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1711922400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1712527200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1713132000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1713736800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1714341600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1714946400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1715551200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1716156000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1716760800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1717365600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1717970400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1718575200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1719180000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1719784800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1720389600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1720994400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1721599200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1722204000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1722808800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1723413600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1724018400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1724623200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1725228000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1725832800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1726437600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1727042400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1727647200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1728252000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1728856800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1729461600000.json
#     Downloaded 169 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1730070000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1730674800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1731279600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1731884400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1732489200000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1733094000000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1733698800000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1734303600000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1734908400000.json
#     Downloaded 168 records
#   Requesting: https://www.smard.de/app/chart_data/1223/DE/1223_DE_hour_1735513200000.json
#     Downloaded 168 records
#
# Combining data...
# Downloaded 26257 records
# Date range: 2022-01-02 23:00:00 to 2024-12-31 23:00:00
# Missing values: 0 (0.0%)
# Saved to cache: ..\data\raw\solar_2022-01-01_2024-12-31_hour.csv
#
# ✅ Daten erfolgreich geladen: 26257 Datenpunkte

# %%
# Erste Inspektion
print("Erste 5 Zeilen:")
display(df.head())

print("\nLetzte 5 Zeilen:")
display(df.tail())

print("\nDatentypen:")
print(df.dtypes)

print(f"\nZeitraum: {df['timestamp'].min()} bis {df['timestamp'].max()}")
print(f"Anzahl Tage: {(df['timestamp'].max() - df['timestamp'].min()).days}")
# Out:
# Erste 5 Zeilen:
#             timestamp    value
# 0 2022-01-02 23:00:00  3676.50
# 1 2022-01-03 00:00:00  3977.75
# 2 2022-01-03 01:00:00  3858.50
# 3 2022-01-03 02:00:00  3870.75
# 4 2022-01-03 03:00:00  4013.75
# Letzte 5 Zeilen:
#                 timestamp   value
# 26252 2024-12-31 19:00:00  5656.0
# 26253 2024-12-31 20:00:00  4381.0
# 26254 2024-12-31 21:00:00  4321.0
# 26255 2024-12-31 22:00:00  3460.5
# 26256 2024-12-31 23:00:00  3269.5
# Datentypen:
# timestamp    datetime64[ns]
# value               float64
# dtype: object
#
# Zeitraum: 2022-01-02 23:00:00 bis 2024-12-31 23:00:00
# Anzahl Tage: 1094

# %% [markdown]
# ## 2. Datenqualität
#
# Überprüfung auf:
# - Fehlende Werte
# - Duplikate
# - Ausreißer
# - Zeitlücken

# %%
print("=" * 60)
print("DATENQUALITÄTS-REPORT")
print("=" * 60)

# Fehlende Werte
missing = df['value'].isna().sum()
missing_pct = missing / len(df) * 100
print(f"\n1. Fehlende Werte: {missing} ({missing_pct:.2f}%)")

# Duplikate
duplicates = df.duplicated(subset=['timestamp']).sum()
print(f"\n2. Duplikate (Timestamp): {duplicates}")

# Zeitlücken prüfen
df_sorted = df.sort_values('timestamp').reset_index(drop=True)
time_diffs = df_sorted['timestamp'].diff()

if RESOLUTION == 'hour':
    expected_diff = pd.Timedelta(hours=1)
elif RESOLUTION == 'day':
    expected_diff = pd.Timedelta(days=1)
else:
    expected_diff = None

if expected_diff:
    gaps = time_diffs[time_diffs > expected_diff]
    print(f"\n3. Zeitlücken (> {expected_diff}): {len(gaps)}")
    if len(gaps) > 0:
        print("   Erste 5 Lücken:")
        for idx in gaps.head().index:
            print(f"     {df_sorted.loc[idx-1, 'timestamp']} -> {df_sorted.loc[idx, 'timestamp']}")

# Statistik
print(f"\n4. Wertebereich:")
print(f"   Min: {df['value'].min():,.0f}")
print(f"   Max: {df['value'].max():,.0f}")
print(f"   Mean: {df['value'].mean():,.0f}")
print(f"   Median: {df['value'].median():,.0f}")
print(f"   Std: {df['value'].std():,.0f}")

# Nullwerte
zeros = (df['value'] == 0).sum()
zeros_pct = zeros / len(df) * 100
print(f"\n5. Nullwerte: {zeros} ({zeros_pct:.2f}%)")

# Negative Werte
negatives = (df['value'] < 0).sum()
print(f"\n6. Negative Werte: {negatives}")

print("\n" + "=" * 60)
# Out:
# ============================================================
# DATENQUALITÄTS-REPORT
# ============================================================
#
# 1. Fehlende Werte: 0 (0.00%)
#
# 2. Duplikate (Timestamp): 0
#
# 3. Zeitlücken (> 0 days 01:00:00): 0
#
# 4. Wertebereich:
#    Min: 2,494
#    Max: 17,173
#    Mean: 9,603
#    Median: 10,264
#    Std: 3,584
#
# 5. Nullwerte: 0 (0.00%)
#
# 6. Negative Werte: 0
#
# ============================================================

# %% [markdown]
# ## 3. Visualisierung - Gesamtzeitreihe

# %%
fig, ax = plt.subplots(figsize=(16, 6))
ax.plot(df['timestamp'], df['value'], linewidth=0.5, alpha=0.8)
ax.set_title(f'{DATA_TYPE.upper()} - Gesamtzeitreihe', fontsize=16, fontweight='bold')
ax.set_xlabel('Datum', fontsize=12)
ax.set_ylabel('Wert [MW]', fontsize=12)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4. Verteilungsanalyse

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

# Histogramm
axes[0].hist(df['value'].dropna(), bins=100, alpha=0.7, edgecolor='black')
axes[0].set_title('Verteilung der Werte', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Wert [MW]')
axes[0].set_ylabel('Häufigkeit')
axes[0].grid(True, alpha=0.3)

# Box-Plot
axes[1].boxplot(df['value'].dropna(), vert=True)
axes[1].set_title('Box-Plot', fontsize=14, fontweight='bold')
axes[1].set_ylabel('Wert [MW]')
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Statistik ausgeben
print("\nStatistische Kennzahlen:")
print(df['value'].describe())
# Out:
# Statistische Kennzahlen:
# count    26257.000000
# mean      9603.410233
# std       3584.329274
# min       2493.750000
# 25%       6485.500000
# 50%      10263.750000
# 75%      12539.250000
# max      17173.250000
# Name: value, dtype: float64

# %% [markdown]
# ## 5. Saisonalität analysieren
#
# ### 5.1 Monatliche Muster

# %%
# Monat und Jahr extrahieren
df['month'] = df['timestamp'].dt.month
df['year'] = df['timestamp'].dt.year
df['hour'] = df['timestamp'].dt.hour
df['dayofweek'] = df['timestamp'].dt.dayofweek  # 0=Montag, 6=Sonntag
df['dayofyear'] = df['timestamp'].dt.dayofyear

# Durchschnitt pro Monat
monthly_avg = df.groupby('month')['value'].mean()

fig, ax = plt.subplots(figsize=(12, 5))
monthly_avg.plot(kind='bar', ax=ax, color='skyblue', edgecolor='black')
ax.set_title('Durchschnittlicher Wert pro Monat', fontsize=14, fontweight='bold')
ax.set_xlabel('Monat')
ax.set_ylabel('Durchschnittswert [MW]')
ax.set_xticklabels(['Jan', 'Feb', 'Mär', 'Apr', 'Mai', 'Jun', 
                    'Jul', 'Aug', 'Sep', 'Okt', 'Nov', 'Dez'], rotation=0)
ax.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.2 Wochentags-Muster

# %%
# Durchschnitt pro Wochentag
weekday_avg = df.groupby('dayofweek')['value'].mean()

fig, ax = plt.subplots(figsize=(10, 5))
weekday_avg.plot(kind='bar', ax=ax, color='coral', edgecolor='black')
ax.set_title('Durchschnittlicher Wert pro Wochentag', fontsize=14, fontweight='bold')
ax.set_xlabel('Wochentag')
ax.set_ylabel('Durchschnittswert [MW]')
ax.set_xticklabels(['Mo', 'Di', 'Mi', 'Do', 'Fr', 'Sa', 'So'], rotation=0)
ax.grid(True, alpha=0.3, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 5.3 Tages-Muster (Stundenprofil)

# %%
if RESOLUTION == 'hour':
    # Durchschnitt pro Stunde
    hourly_avg = df.groupby('hour')['value'].mean()
    
    fig, ax = plt.subplots(figsize=(14, 5))
    hourly_avg.plot(ax=ax, marker='o', linewidth=2, markersize=6, color='green')
    ax.set_title('Durchschnittliches Tagesprofil (pro Stunde)', fontsize=14, fontweight='bold')
    ax.set_xlabel('Stunde des Tages')
    ax.set_ylabel('Durchschnittswert [MW]')
    ax.set_xticks(range(24))
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()
else:
    print("Stundenprofil nur für stündliche Auflösung verfügbar")

# %% [markdown]
# ### 5.4 Jahresverlauf

# %%
# Tagesdurchschnitt
daily_avg = df.groupby(df['timestamp'].dt.date)['value'].mean()

fig, ax = plt.subplots(figsize=(16, 5))
ax.plot(daily_avg.index, daily_avg.values, linewidth=1)
ax.set_title('Täglicher Durchschnittswert', fontsize=14, fontweight='bold')
ax.set_xlabel('Datum')
ax.set_ylabel('Durchschnitt [MW]')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Autokorrelation (ACF) und Partielle Autokorrelation (PACF)
#
# Wichtig für:
# - Erkennung von Abhängigkeiten
# - ARIMA-Parameter-Auswahl

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Nur nicht-fehlende Werte
values_clean = df['value'].dropna()

fig, axes = plt.subplots(2, 1, figsize=(16, 10))

# ACF
plot_acf(values_clean, lags=168, ax=axes[0])  # 7 Tage für stündliche Daten
axes[0].set_title('Autokorrelationsfunktion (ACF)', fontsize=14, fontweight='bold')
axes[0].set_xlabel('Lag')

# PACF
plot_pacf(values_clean, lags=168, ax=axes[1])
axes[1].set_title('Partielle Autokorrelationsfunktion (PACF)', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Lag')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Stationaritätstest
#
# Augmented Dickey-Fuller Test:
# - H0: Zeitreihe ist nicht-stationär
# - H1: Zeitreihe ist stationär
# - p-value < 0.05 → Zeitreihe ist stationär

# %%
from statsmodels.tsa.stattools import adfuller, kpss

# ADF Test
result_adf = adfuller(values_clean)

print("=" * 60)
print("STATIONARITÄTSTEST")
print("=" * 60)
print("\nAugmented Dickey-Fuller Test:")
print(f"  ADF Statistic: {result_adf[0]:.6f}")
print(f"  p-value: {result_adf[1]:.6f}")
print(f"  Critical Values:")
for key, value in result_adf[4].items():
    print(f"    {key}: {value:.3f}")

if result_adf[1] < 0.05:
    print("\n  ✅ Zeitreihe ist STATIONÄR (p < 0.05)")
else:
    print("\n  ⚠️  Zeitreihe ist NICHT-STATIONÄR (p >= 0.05)")
    print("      → Differenzierung könnte notwendig sein")

# KPSS Test (zusätzlich)
try:
    result_kpss = kpss(values_clean, regression='ct')
    print("\n\nKPSS Test (Trend-Stationarität):")
    print(f"  KPSS Statistic: {result_kpss[0]:.6f}")
    print(f"  p-value: {result_kpss[1]:.6f}")
    
    if result_kpss[1] > 0.05:
        print("\n  ✅ Zeitreihe ist TREND-STATIONÄR (p > 0.05)")
    else:
        print("\n  ⚠️  Zeitreihe ist NICHT TREND-STATIONÄR (p <= 0.05)")
except:
    print("\nKPSS Test konnte nicht durchgeführt werden")

print("\n" + "=" * 60)
# Out:
# ============================================================
# STATIONARITÄTSTEST
# ============================================================
#
# Augmented Dickey-Fuller Test:
#   ADF Statistic: -11.057735
#   p-value: 0.000000
#   Critical Values:
#     1%: -3.431
#     5%: -2.862
#     10%: -2.567
#
#   ✅ Zeitreihe ist STATIONÄR (p < 0.05)
#
#
# KPSS Test (Trend-Stationarität):
#   KPSS Statistic: 0.632777
#   p-value: 0.010000
#
#   ⚠️  Zeitreihe ist NICHT TREND-STATIONÄR (p <= 0.05)
#
# ============================================================
# C:\Users\Christian\AppData\Local\Temp\ipykernel_18124\2332959990.py:24: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   result_kpss = kpss(values_clean, regression='ct')

# %% [markdown]
# ## 8. Zusammenfassung & Nächste Schritte
#
# ### Erkenntnisse aus der EDA:
#
# **Bitte trage hier deine Beobachtungen ein:**
#
# 1. **Datenqualität:**
#    - [ ] Fehlende Werte vorhanden? → Strategie festlegen
#    - [ ] Ausreißer vorhanden? → Behandlung notwendig?
#    - [ ] Zeitlücken? → Interpolation?
#
# 2. **Saisonalität:**
#    - [ ] Tägliche Saisonalität erkennbar?
#    - [ ] Wöchentliche Saisonalität?
#    - [ ] Jährliche Saisonalität?
#
# 3. **Trend:**
#    - [ ] Aufwärtstrend?
#    - [ ] Abwärtstrend?
#    - [ ] Kein Trend?
#
# 4. **Stationarität:**
#    - [ ] Stationär?
#    - [ ] Differenzierung notwendig?
#
# ### Nächste Schritte:
#
# 1. **Datenaufbereitung** → `02_data_preprocessing.ipynb`
#    - Fehlende Werte behandeln
#    - Ausreißer behandeln
#    - Features engineering
#    - Train/Test/Validation Split
#
# 2. **Baseline-Modelle** → `03_baseline_models.ipynb`
#    - Naive Forecast
#    - Seasonal Naive
#    - Moving Average
#
# 3. **Statistische Modelle** → `04_statistical_models.ipynb`
#    - SARIMA(X)
#    - ETS
#
# 4. **Machine Learning** → `05_ml_tree_models.ipynb`
#    - XGBoost, LightGBM, CatBoost
#
# 5. **Deep Learning** → `06_deep_learning_models.ipynb`
#    - LSTM, GRU
#
# 6. **Advanced Models** → `07_advanced_models.ipynb`
#    - TFT, N-BEATS
#
# 7. **Model Comparison** → `08_model_comparison.ipynb`

# %%
# Optional: Aufbereitete Daten speichern für weitere Notebooks
output_file = Path('../data/processed') / f'{DATA_TYPE}_{START_DATE}_{END_DATE}_initial.csv'
df.to_csv(output_file, index=False)
print(f"✅ Daten gespeichert: {output_file}")
# Out:
# ✅ Daten gespeichert: ..\data\processed\solar_2022-01-01_2024-12-31_initial.csv
